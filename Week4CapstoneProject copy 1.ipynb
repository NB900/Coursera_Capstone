# %% [markdown]
# ## Introduction/Business Problem
# Vegan or vegetarian diet is the latest trend in restaurant industry. As the inclination of people towards plant based diet is increasing, the demand for vegan or vegetarian restaurants is rising. There are few vegan or vegetarian restaurants available but there is still a big void to fill. This project will help bridge this gap. The audience of this project will be the people who want to open a restaurant in Toronto. This project will help them by providing them the area names where there is high potential for a vegan or vegetarian restaurant to succeed.

# %% [markdown]
# ## Data
# In this project we will use the Foursquare location data to search for vegan or vegetarian restaurants in Toronto. We will then get different boroughs of Toronto using the data from Wikipedia. After getting the boroughss data we will use this data to get the number of vegan or vegetarian restaurants in different boroughs of Toronto. Thereafter, we will compare the boroughs to find the ones with the least number of vegan or vegetarian restaurants. Finally, we will suggest the user the best places to open vegan or vegetarian restaurants in Toronto. For example, if "Harbourfront, Regent Park" has 60 vegan or vegetarian restaurants but "Central Bay Street" has 10 vegan or vegetarian restaurants, then "Central Bay Street" could be a possible suggestion.
#
# Link to Wikipedia file: 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'.

# %% [markdown]
# ## Methodology

# %%
# !conda install beautifulsoup4
# !conda install lxml
# !conda install requests
# Out:
# Fetching package metadata ...........
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# beautifulsoup4            4.6.3                    py35_0
# Fetching package metadata ...........
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# lxml                      4.2.5            py35hefd8a0e_0
# Fetching package metadata ...........
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# requests                  2.19.1                   py35_0

# %%
from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd
import numpy as np

# %%
source = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

# %%
soup = BeautifulSoup(source,'lxml')

# %%
table = soup.find_all('table')[0]
#table

# %%
#print(soup.prettify())

# %%
table_raw = soup.find('table', 'tr',class_='wikitable sortable')

# %%
#print(table_raw.prettify())

# %%
b = table_raw.tbody.text
#b

# %%
c = b.split('\n\n\n')
#c

# %%
d = pd.DataFrame(c)
#d

# %%
new = d[0].str.split('\n',n=0,expand = True)

new.drop(columns =[3,4], inplace = True) 
new.drop([0],inplace=True)
new.columns=['PostalCode','Borough','Neighborhood']
new = new.reset_index(drop=True)
new.shape
new.tail()
# Out:
#     PostalCode       Borough           Neighborhood
# 284        M8Z     Etobicoke              Mimico NW
# 285        M8Z     Etobicoke     The Queensway West
# 286        M8Z     Etobicoke  Royal York South West
# 287        M8Z     Etobicoke         South of Bloor
# 288        M9Z  Not assigned           Not assigned

# %%
new.shape
# Out:
# (289, 3)

# %%
for i in range (0,(len(new['Borough']))):
    
    if(new.iloc[i,1] == 'Not assigned'):
        new.iloc[i,1]=None
    else:
        pass
print(new.head())
# Out:
#   PostalCode           Borough      Neighborhood
# 0        M1A              None      Not assigned
# 1        M2A              None      Not assigned
# 2        M3A        North York         Parkwoods
# 3        M4A        North York  Victoria Village
# 4        M5A  Downtown Toronto      Harbourfront

# %%
new = new.dropna(subset=["Borough"],axis=0)
new = new.reset_index(drop=True)
new.head()
# Out:
#   PostalCode           Borough      Neighborhood
# 0        M3A        North York         Parkwoods
# 1        M4A        North York  Victoria Village
# 2        M5A  Downtown Toronto      Harbourfront
# 3        M5A  Downtown Toronto       Regent Park
# 4        M6A        North York  Lawrence Heights

# %%
for i in range (0,(len(new['Neighborhood']))):
    if(new.iloc[i,2] == 'Not assigned'):
        new.iloc[i,2]=new.iloc[i,1]
    else:
        pass
new.head(10)
# Out:
#   PostalCode           Borough      Neighborhood
# 0        M3A        North York         Parkwoods
# 1        M4A        North York  Victoria Village
# 2        M5A  Downtown Toronto      Harbourfront
# 3        M5A  Downtown Toronto       Regent Park
# 4        M6A        North York  Lawrence Heights
# 5        M6A        North York    Lawrence Manor
# 6        M7A      Queen's Park      Queen's Park
# 7        M9A         Etobicoke  Islington Avenue
# 8        M1B       Scarborough             Rouge
# 9        M1B       Scarborough           Malvern

# %%
group1 = new["Neighborhood"].groupby(new["PostalCode"]).agg([('Neighborhood', ', '.join)])
group1=group1.reset_index()
print(group1.size)
# Out:
# 206

# %%
df_inner = pd.merge(new, group1, on = "PostalCode", how ='inner')
df_inner.head()
# Out:
#   PostalCode           Borough    Neighborhood_x  \
# 0        M3A        North York         Parkwoods
# 1        M4A        North York  Victoria Village
# 2        M5A  Downtown Toronto      Harbourfront
# 3        M5A  Downtown Toronto       Regent Park
# 4        M6A        North York  Lawrence Heights
#
#                      Neighborhood_y
# 0                         Parkwoods
# 1                  Victoria Village
# 2         Harbourfront, Regent Park
# 3         Harbourfront, Regent Park
# 4  Lawrence Heights, Lawrence Manor

# %%
df_inner.drop(columns=["Neighborhood_x"], inplace=True)

# %%
df_inner.shape
# Out:
# (212, 3)

# %%
df_inner = df_inner.drop_duplicates()

# %%
df_inner.columns=['PostalCode','Borough','Neighborhood']
df_inner = df_inner.reset_index(drop=True)
df_inner.shape
# Out:
# (103, 3)

# %%
df_inner.head()
# Out:
#   PostalCode           Borough                      Neighborhood
# 0        M3A        North York                         Parkwoods
# 1        M4A        North York                  Victoria Village
# 2        M5A  Downtown Toronto         Harbourfront, Regent Park
# 3        M6A        North York  Lawrence Heights, Lawrence Manor
# 4        M7A      Queen's Park                      Queen's Park

# %%
#Number of rows in the final dataframe
df_inner.shape
# Out:
# (103, 3)

# %%
geo_cord = pd.read_csv('https://cocl.us/Geospatial_data')

# %%
geo_cord.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
geo_cord.columns=["PostalCode","Latitude","Longitude"]

# %%
geo_df = pd.merge(df_inner,geo_cord, on="PostalCode", how="inner")
geo_df.head()
# Out:
#   PostalCode           Borough                      Neighborhood   Latitude  \
# 0        M3A        North York                         Parkwoods  43.753259
# 1        M4A        North York                  Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Harbourfront, Regent Park  43.654260
# 3        M6A        North York  Lawrence Heights, Lawrence Manor  43.718518
# 4        M7A      Queen's Park                      Queen's Park  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %%
geo_df.drop(columns=["PostalCode"], inplace=True)
geo_df.head()
# Out:
#             Borough                      Neighborhood   Latitude  Longitude
# 0        North York                         Parkwoods  43.753259 -79.329656
# 1        North York                  Victoria Village  43.725882 -79.315572
# 2  Downtown Toronto         Harbourfront, Regent Park  43.654260 -79.360636
# 3        North York  Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 4      Queen's Park                      Queen's Park  43.662301 -79.389494

# %%
geo_df.drop(columns=["Neighborhood"], inplace=True)
geo_df.head()
# Out:
#             Borough   Latitude  Longitude
# 0        North York  43.753259 -79.329656
# 1        North York  43.725882 -79.315572
# 2  Downtown Toronto  43.654260 -79.360636
# 3        North York  43.718518 -79.464763
# 4      Queen's Park  43.662301 -79.389494

# %%
df_fresh = geo_df.drop_duplicates("Borough")

# %%
df_fresh = df_fresh.reset_index(drop=True)
df_fresh
# Out:
#              Borough   Latitude  Longitude
# 0         North York  43.753259 -79.329656
# 1   Downtown Toronto  43.654260 -79.360636
# 2       Queen's Park  43.662301 -79.389494
# 3          Etobicoke  43.667856 -79.532242
# 4        Scarborough  43.806686 -79.194353
# 5          East York  43.706397 -79.309937
# 6               York  43.693781 -79.428191
# 7       East Toronto  43.676357 -79.293031
# 8       West Toronto  43.669005 -79.442259
# 9    Central Toronto  43.728020 -79.388790
# 10       Mississauga  43.636966 -79.615819

# %%
df_latest = df_fresh

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.17.0-py_0 conda-forge
#
# geographiclib- 100% |################################| Time: 0:00:00  23.02 MB/s
# geopy-1.17.0-p 100% |################################| Time: 0:00:00   1.29 MB/s
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
# altair-2.2.2-p 100% |################################| Time: 0:00:00  55.06 MB/s
# branca-0.3.1-p 100% |################################| Time: 0:00:00  34.87 MB/s
# vincent-0.4.4- 100% |################################| Time: 0:00:00  39.51 MB/s
# folium-0.5.0-p 100% |################################| Time: 0:00:00  49.13 MB/s
# Libraries imported.

# %%
CLIENT_ID = '' # your Foursquare ID
CLIENT_SECRET = '' # your Foursquare Secret
VERSION = '' # Foursquare API version

#print('Your credentails:')
#print('CLIENT_ID: ' + CLIENT_ID)
#print('CLIENT_SECRET:' + CLIENT_SECRET)

# %%
veg_df=pd.DataFrame(columns=['name','categories','lat','lng','address','Borough'])
veg_df
# Out:
# Empty DataFrame
# Columns: [name, categories, lat, lng, address, Borough]
# Index: []

# %%
for i in range(df_latest.shape[0]):
    print(df_latest['Borough'][i],df_latest['Latitude'][i],df_latest['Longitude'][i])

    address = df_latest['Borough'][i]
    #geolocator = Nominatim()
    #location = geolocator.geocode(address)
    latitude = df_latest['Latitude'][i]
    longitude = df_latest['Longitude'][i]
    #print('The geograpical coordinate of {} are {}, {}.'.format(address,latitude, longitude))
    search_query = 'Vegetarian / Vegan Restaurant'
    LIMIT = 500 # limit of number of venues returned by Foursquare API
#radius = 10000 # define radius
#url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&query={}&intent={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query,'browse')
    #url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&near={}&v={}&query={}&intent={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, address, VERSION, search_query,'browse',LIMIT)
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&query={}&intent={}&limit={}'.format(
        CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query,'browse',LIMIT)
    results = requests.get(url).json()
    # function that extracts the category of the venue
    def get_category_type(row):
        try:
            categories_list = row['categories']
        except:
            categories_list = row['venue.categories']
        
        if len(categories_list) == 0:
            return None
        else:
            return categories_list[0]['name']
    #print(results)
    venues = results['response']['groups'][0]['items'] 
    nearby_venues = json_normalize(venues) # flatten JSON
    nearby_venues.head()
    # filter columns
    filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng','venue.location.address']
    nearby_venues =nearby_venues.loc[:, filtered_columns]
    # filter the category for each row
    nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

    # clean columns
    nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
    nearby_venues['Borough']=address
    veg_df=veg_df.append(nearby_venues)
    #print(nearby_venues)
# Out:
# North York 43.7532586 -79.3296565
# Downtown Toronto 43.6542599 -79.3606359
# Queen's Park 43.6623015 -79.3894938
# Etobicoke 43.6678556 -79.5322424
# Scarborough 43.8066863 -79.1943534
# East York 43.7063972 -79.309937
# York 43.6937813 -79.4281914
# East Toronto 43.6763574 -79.2930312
# West Toronto 43.6690051 -79.4422593
# Central Toronto 43.7280205 -79.3887901
# Mississauga 43.6369656 -79.615819

# %% [markdown]
# ## Results Section

# %% [markdown]
# The following table shows different boroughs in Toronto and the Vegetarian / Vegan Restaurants present in them.

# %%
veg_df
# Out:
#                                      name                     categories  \
# 0                                 Freshii  Vegetarian / Vegan Restaurant
# 1                                Pita Pit  Vegetarian / Vegan Restaurant
# 2                    Ital Vital Rastarant  Vegetarian / Vegan Restaurant
# 3                                   Fresh  Vegetarian / Vegan Restaurant
# 4   Lotus Pond Vegetarian Restaurant 蓮花素食  Vegetarian / Vegan Restaurant
# 5                     Gourmet Malaysia 膳園  Vegetarian / Vegan Restaurant
# 6                              Magic Oven  Vegetarian / Vegan Restaurant
# 7                            Udupi Palace  Vegetarian / Vegan Restaurant
# 8                         Tori's Bakeshop  Vegetarian / Vegan Restaurant
# 9                               A1 Sweets  Vegetarian / Vegan Restaurant
# 10                                 B.Good  Vegetarian / Vegan Restaurant
# 11   Graceful Vegetarian Restaurant 法海素食軒  Vegetarian / Vegan Restaurant
# 12       Schledermann Danish Vegan Bakery  Vegetarian / Vegan Restaurant
# 13                                 Planta  Vegetarian / Vegan Restaurant
# 14                            Simon's Wok  Vegetarian / Vegan Restaurant
# 15                 Green Earth Vegetarian  Vegetarian / Vegan Restaurant
# 16                         Fresh on Bloor  Vegetarian / Vegan Restaurant
# 17                              Govinda's  Vegetarian / Vegan Restaurant
# 18                        Castro's Lounge  Vegetarian / Vegan Restaurant
# 19                    One Love Vegetarian  Vegetarian / Vegan Restaurant
# 20                        Urban Herbivore  Vegetarian / Vegan Restaurant
# 21                  Live Organic Food Bar  Vegetarian / Vegan Restaurant
# 22                       Vegetarian Haven  Vegetarian / Vegan Restaurant
# 23                               Hibiscus  Vegetarian / Vegan Restaurant
# 24                            Grasshopper  Vegetarian / Vegan Restaurant
# 25                             Magic Oven  Vegetarian / Vegan Restaurant
# 26                        Urban Herbivore  Vegetarian / Vegan Restaurant
# 27                       Fresh On Spadina  Vegetarian / Vegan Restaurant
# 28                            King's Cafe  Vegetarian / Vegan Restaurant
# 29                               YamChops  Vegetarian / Vegan Restaurant
# 30                               Karine's  Vegetarian / Vegan Restaurant
# 31                              Rosalinda  Vegetarian / Vegan Restaurant
# 32                      The Hogtown Vegan  Vegetarian / Vegan Restaurant
# 33                Saigon Lotus Restaurant  Vegetarian / Vegan Restaurant
# 34                          Cosmic Treats  Vegetarian / Vegan Restaurant
# 35                          Kupfert & Kim  Vegetarian / Vegan Restaurant
# 36                Little India Restaurant  Vegetarian / Vegan Restaurant
# 37                    Buddha's Vegetarian  Vegetarian / Vegan Restaurant
# 38   Kupfert & Kim (First Canadian Place)  Vegetarian / Vegan Restaurant
# 39                          Hogtown Vegan  Vegetarian / Vegan Restaurant
# 40                     Bunner's Bake Shop  Vegetarian / Vegan Restaurant
# 41                     Superfood Eateries  Vegetarian / Vegan Restaurant
# 42        Annapurna Vegetarian Restaurant  Vegetarian / Vegan Restaurant
# 43           Greens Vegetarian Restaurant  Vegetarian / Vegan Restaurant
# 44   The Buddhist Vegetarian Kitchen 佛海齋廚  Vegetarian / Vegan Restaurant
# 45          Gourmet Vegetarian Restaurant  Vegetarian / Vegan Restaurant
# 46                                 Veghed  Vegetarian / Vegan Restaurant
# 47                          Kupfert & Kim  Vegetarian / Vegan Restaurant
# 48                    E.L. Ruddy Co. Cafe  Vegetarian / Vegan Restaurant
# 49                              The Goods  Vegetarian / Vegan Restaurant
# 50                            Live Market  Vegetarian / Vegan Restaurant
# 51    Through Being Cool Vegan Baking Co.  Vegetarian / Vegan Restaurant
# 52                              Hello 123  Vegetarian / Vegan Restaurant
# 53                                Freshii  Vegetarian / Vegan Restaurant
# 54                                 Planta  Vegetarian / Vegan Restaurant
# 55                                Freshii  Vegetarian / Vegan Restaurant
# 56                         Feel Good Guru  Vegetarian / Vegan Restaurant
# 57                            Mocha Mocha  Vegetarian / Vegan Restaurant
# 58                               Doomie's  Vegetarian / Vegan Restaurant
# 59                    The Social Gardener  Vegetarian / Vegan Restaurant
# 60                           Milk N Honey  Vegetarian / Vegan Restaurant
# 61                                 nutbar  Vegetarian / Vegan Restaurant
# 62                   Crave Healthy Habits  Vegetarian / Vegan Restaurant
# 63                         Bolt Fresh Bar  Vegetarian / Vegan Restaurant
# 64                     Rawlicious Markham  Vegetarian / Vegan Restaurant
# 65              Afghan Village Restaurant      Middle Eastern Restaurant
# 66      Tenon Vegetarian Cuisine 天恩中日素食料理  Vegetarian / Vegan Restaurant
# 67       Kupfert & Kim (Brookfield Place)  Vegetarian / Vegan Restaurant
# 68                             Cruda Cafe  Vegetarian / Vegan Restaurant
# 69                               Cafe 668  Vegetarian / Vegan Restaurant
# 70      Wutai Vegetarian Restaurant 五台山素宴  Vegetarian / Vegan Restaurant
# 71                               Cultures  Vegetarian / Vegan Restaurant
# 72                        Mythology Diner  Vegetarian / Vegan Restaurant
# 73                    The Green Beet Cafe  Vegetarian / Vegan Restaurant
# 74                                Freshii  Vegetarian / Vegan Restaurant
# 75                                   Awai  Vegetarian / Vegan Restaurant
# 76                      Harvest Noon Cafe  Vegetarian / Vegan Restaurant
# 77                                Freshii  Vegetarian / Vegan Restaurant
# 78                        süüp health bar  Vegetarian / Vegan Restaurant
# 79            Veda Healthy Indian Takeout  Vegetarian / Vegan Restaurant
# 80                    Rancho Relaxo To Go  Vegetarian / Vegan Restaurant
# 81                         Fresh On Front  Vegetarian / Vegan Restaurant
# 82                                Ghazale  Vegetarian / Vegan Restaurant
# 83                        Naturally Yours  Vegetarian / Vegan Restaurant
# 84                     Bo De Duyen 菩提緣素食樓  Vegetarian / Vegan Restaurant
# 85                                freshii  Vegetarian / Vegan Restaurant
# 86                             Calii Love  Vegetarian / Vegan Restaurant
# 87                                Freshii  Vegetarian / Vegan Restaurant
# 88                            iQ Food Co.  Vegetarian / Vegan Restaurant
# 89                                Freshii  Vegetarian / Vegan Restaurant
# 90                                Freshii  Vegetarian / Vegan Restaurant
# 0                         Urban Herbivore  Vegetarian / Vegan Restaurant
# 1                  Green Earth Vegetarian  Vegetarian / Vegan Restaurant
# 2    Kupfert & Kim (First Canadian Place)  Vegetarian / Vegan Restaurant
# 3                             Simon's Wok  Vegetarian / Vegan Restaurant
# 4                               Rosalinda  Vegetarian / Vegan Restaurant
# 5                           Kupfert & Kim  Vegetarian / Vegan Restaurant
# 6                 Little India Restaurant  Vegetarian / Vegan Restaurant
# 7                                Karine's  Vegetarian / Vegan Restaurant
# 8                      Superfood Eateries  Vegetarian / Vegan Restaurant
# 9                                  Planta  Vegetarian / Vegan Restaurant
# 10                             Cruda Cafe  Vegetarian / Vegan Restaurant
# 11                   Crave Healthy Habits  Vegetarian / Vegan Restaurant
# 12       Kupfert & Kim (Brookfield Place)  Vegetarian / Vegan Restaurant
# 13                         Fresh On Front  Vegetarian / Vegan Restaurant
# 14                        Naturally Yours  Vegetarian / Vegan Restaurant
# 15                        süüp health bar  Vegetarian / Vegan Restaurant
# 16                                Freshii  Vegetarian / Vegan Restaurant
# 17                                freshii  Vegetarian / Vegan Restaurant
# 18                                Freshii  Vegetarian / Vegan Restaurant
# 19                              Basil Box               Asian Restaurant
# 20                                Freshii  Vegetarian / Vegan Restaurant
# 0                        Vegetarian Haven  Vegetarian / Vegan Restaurant
# 1                                  Planta  Vegetarian / Vegan Restaurant
# 2                         Urban Herbivore  Vegetarian / Vegan Restaurant
# 3                                Karine's  Vegetarian / Vegan Restaurant
# 4                          Fresh on Bloor  Vegetarian / Vegan Restaurant
# 5                             Grasshopper  Vegetarian / Vegan Restaurant
# 6                                Hibiscus  Vegetarian / Vegan Restaurant
# 7                         Urban Herbivore  Vegetarian / Vegan Restaurant
# 8                 Saigon Lotus Restaurant  Vegetarian / Vegan Restaurant
# 9                             King's Cafe  Vegetarian / Vegan Restaurant
# 10                          Cosmic Treats  Vegetarian / Vegan Restaurant
# 11                Little India Restaurant  Vegetarian / Vegan Restaurant
# 12                     Bunner's Bake Shop  Vegetarian / Vegan Restaurant
# 13                              Rosalinda  Vegetarian / Vegan Restaurant
# 14                      The Hogtown Vegan  Vegetarian / Vegan Restaurant
# 15                       Fresh On Spadina  Vegetarian / Vegan Restaurant
# 16                    Buddha's Vegetarian  Vegetarian / Vegan Restaurant
# 17                          Kupfert & Kim  Vegetarian / Vegan Restaurant
# 18           Greens Vegetarian Restaurant  Vegetarian / Vegan Restaurant
# 19                     Superfood Eateries  Vegetarian / Vegan Restaurant
# 20                              Govinda's  Vegetarian / Vegan Restaurant
# 21                    The Green Beet Cafe  Vegetarian / Vegan Restaurant
# 22                                Freshii  Vegetarian / Vegan Restaurant
# 23                                 Planta  Vegetarian / Vegan Restaurant
# 24            Veda Healthy Indian Takeout  Vegetarian / Vegan Restaurant
# 25                                Freshii  Vegetarian / Vegan Restaurant
# 26                        süüp health bar  Vegetarian / Vegan Restaurant
# 27                      Harvest Noon Cafe  Vegetarian / Vegan Restaurant
# 28                   Crave Healthy Habits  Vegetarian / Vegan Restaurant
# 29                              Basil Box               Asian Restaurant
# 30                                Freshii                    Salad Place
# 31                     Bo De Duyen 菩提緣素食樓  Vegetarian / Vegan Restaurant
# 32                                freshii  Vegetarian / Vegan Restaurant
# 33                             Calii Love  Vegetarian / Vegan Restaurant
# 0                                    Awai  Vegetarian / Vegan Restaurant
# 1                           Hogtown Vegan  Vegetarian / Vegan Restaurant
# 2     Through Being Cool Vegan Baking Co.  Vegetarian / Vegan Restaurant
# 3                     E.L. Ruddy Co. Cafe  Vegetarian / Vegan Restaurant
# 4                                Doomie's  Vegetarian / Vegan Restaurant
# 5           Thrive Organic Kitchen & Café  Vegetarian / Vegan Restaurant
# 6                         Mythology Diner  Vegetarian / Vegan Restaurant
# 0                               A1 Sweets  Vegetarian / Vegan Restaurant
# 1   Lotus Pond Vegetarian Restaurant 蓮花素食  Vegetarian / Vegan Restaurant
# 2                     Gourmet Malaysia 膳園  Vegetarian / Vegan Restaurant
# 3                                Pita Pit  Vegetarian / Vegan Restaurant
# 4    Graceful Vegetarian Restaurant 法海素食軒  Vegetarian / Vegan Restaurant
# 5                      Rawlicious Markham  Vegetarian / Vegan Restaurant
# 6       Tenon Vegetarian Cuisine 天恩中日素食料理  Vegetarian / Vegan Restaurant
# 7    The Buddhist Vegetarian Kitchen 佛海齋廚  Vegetarian / Vegan Restaurant
# 0                         Tori's Bakeshop  Vegetarian / Vegan Restaurant
# 1                    Ital Vital Rastarant  Vegetarian / Vegan Restaurant
# 2                            Udupi Palace  Vegetarian / Vegan Restaurant
# 3                              Magic Oven  Vegetarian / Vegan Restaurant
# 4                         Castro's Lounge  Vegetarian / Vegan Restaurant
# 5                             Simon's Wok  Vegetarian / Vegan Restaurant
# 6                  Green Earth Vegetarian  Vegetarian / Vegan Restaurant
# 7                                   Fresh  Vegetarian / Vegan Restaurant
# 8                                  B.Good  Vegetarian / Vegan Restaurant
# 9                     The Social Gardener  Vegetarian / Vegan Restaurant
# 10                            Mocha Mocha  Vegetarian / Vegan Restaurant
# 11              Afghan Village Restaurant      Middle Eastern Restaurant
# 0                     One Love Vegetarian  Vegetarian / Vegan Restaurant
# 1                                   Fresh  Vegetarian / Vegan Restaurant
# 2                          Fresh on Bloor  Vegetarian / Vegan Restaurant
# 3                   Live Organic Food Bar  Vegetarian / Vegan Restaurant
# 4                           Hogtown Vegan  Vegetarian / Vegan Restaurant
# 5                              Magic Oven  Vegetarian / Vegan Restaurant
# 6                               Govinda's  Vegetarian / Vegan Restaurant
# 7                                YamChops  Vegetarian / Vegan Restaurant
# 8                                  Planta  Vegetarian / Vegan Restaurant
# 9         Annapurna Vegetarian Restaurant  Vegetarian / Vegan Restaurant
# 10                               Hibiscus  Vegetarian / Vegan Restaurant
# 11                            Grasshopper  Vegetarian / Vegan Restaurant
# 12    Through Being Cool Vegan Baking Co.  Vegetarian / Vegan Restaurant
# 13                        Urban Herbivore  Vegetarian / Vegan Restaurant
# 14                       Vegetarian Haven  Vegetarian / Vegan Restaurant
# 15                      The Hogtown Vegan  Vegetarian / Vegan Restaurant
# 16                            King's Cafe  Vegetarian / Vegan Restaurant
# 17                                 Veghed  Vegetarian / Vegan Restaurant
# 18                                 B.Good  Vegetarian / Vegan Restaurant
# 19                          Cosmic Treats  Vegetarian / Vegan Restaurant
# 20                    E.L. Ruddy Co. Cafe  Vegetarian / Vegan Restaurant
# 21                    Buddha's Vegetarian  Vegetarian / Vegan Restaurant
# 22                Saigon Lotus Restaurant  Vegetarian / Vegan Restaurant
# 23                     Bunner's Bake Shop  Vegetarian / Vegan Restaurant
# 24                              The Goods  Vegetarian / Vegan Restaurant
# 25           Greens Vegetarian Restaurant  Vegetarian / Vegan Restaurant
# 26                                Freshii  Vegetarian / Vegan Restaurant
# 27                                  Fresh  Vegetarian / Vegan Restaurant
# 28                         Feel Good Guru  Vegetarian / Vegan Restaurant
# 29                               Cafe 668  Vegetarian / Vegan Restaurant
# 30                                 nutbar  Vegetarian / Vegan Restaurant
# 31                    Rancho Relaxo To Go  Vegetarian / Vegan Restaurant
# 32                                Ghazale  Vegetarian / Vegan Restaurant
# 33                           Milk N Honey  Vegetarian / Vegan Restaurant
# 34                      Harvest Noon Cafe  Vegetarian / Vegan Restaurant
# 35                               Cultures  Vegetarian / Vegan Restaurant
# 36                    The Green Beet Cafe  Vegetarian / Vegan Restaurant
# 37                                Freshii  Vegetarian / Vegan Restaurant
# 38            Veda Healthy Indian Takeout  Vegetarian / Vegan Restaurant
# 39                                Freshii                    Salad Place
# 40                        süüp health bar  Vegetarian / Vegan Restaurant
# 0                         Tori's Bakeshop  Vegetarian / Vegan Restaurant
# 1                         Castro's Lounge  Vegetarian / Vegan Restaurant
# 2                            Udupi Palace  Vegetarian / Vegan Restaurant
# 3                              Magic Oven  Vegetarian / Vegan Restaurant
# 4                             Simon's Wok  Vegetarian / Vegan Restaurant
# 5                  Green Earth Vegetarian  Vegetarian / Vegan Restaurant
# 6                    Ital Vital Rastarant  Vegetarian / Vegan Restaurant
# 7                           Kupfert & Kim  Vegetarian / Vegan Restaurant
# 8                     The Social Gardener  Vegetarian / Vegan Restaurant
# 9                                  Planta  Vegetarian / Vegan Restaurant
# 10                            Mocha Mocha  Vegetarian / Vegan Restaurant
# 11       Kupfert & Kim (Brookfield Place)  Vegetarian / Vegan Restaurant
# 12                             Cruda Cafe  Vegetarian / Vegan Restaurant
# 13                         Fresh On Front  Vegetarian / Vegan Restaurant
# 14              Afghan Village Restaurant      Middle Eastern Restaurant
# 0                           Hogtown Vegan  Vegetarian / Vegan Restaurant
# 1     Through Being Cool Vegan Baking Co.  Vegetarian / Vegan Restaurant
# 2                                YamChops  Vegetarian / Vegan Restaurant
# 3                     One Love Vegetarian  Vegetarian / Vegan Restaurant
# 4                     E.L. Ruddy Co. Cafe  Vegetarian / Vegan Restaurant
# 5                                  Veghed  Vegetarian / Vegan Restaurant
# 6                          Fresh on Bloor  Vegetarian / Vegan Restaurant
# 7                               The Goods  Vegetarian / Vegan Restaurant
# 8                   Live Organic Food Bar  Vegetarian / Vegan Restaurant
# 9         Annapurna Vegetarian Restaurant  Vegetarian / Vegan Restaurant
# 10                            Grasshopper  Vegetarian / Vegan Restaurant
# 11                      The Hogtown Vegan  Vegetarian / Vegan Restaurant
# 12                               Doomie's  Vegetarian / Vegan Restaurant
# 13                        Urban Herbivore  Vegetarian / Vegan Restaurant
# 14                            Live Market  Vegetarian / Vegan Restaurant
# 15                                  Fresh  Vegetarian / Vegan Restaurant
# 16                              Hello 123  Vegetarian / Vegan Restaurant
# 17                             Magic Oven  Vegetarian / Vegan Restaurant
# 18                    Buddha's Vegetarian  Vegetarian / Vegan Restaurant
# 19                         Bolt Fresh Bar  Vegetarian / Vegan Restaurant
# 20                              Govinda's  Vegetarian / Vegan Restaurant
# 21                         Feel Good Guru  Vegetarian / Vegan Restaurant
# 22                                   Awai  Vegetarian / Vegan Restaurant
# 23                        Mythology Diner  Vegetarian / Vegan Restaurant
# 24                               Cafe 668  Vegetarian / Vegan Restaurant
# 25                                Ghazale  Vegetarian / Vegan Restaurant
# 26                                Freshii  Vegetarian / Vegan Restaurant
# 27                    Rancho Relaxo To Go  Vegetarian / Vegan Restaurant
# 28                      Harvest Noon Cafe  Vegetarian / Vegan Restaurant
# 29                    The Green Beet Cafe  Vegetarian / Vegan Restaurant
# 0                                   Fresh  Vegetarian / Vegan Restaurant
# 1                                  B.Good  Vegetarian / Vegan Restaurant
# 2                                 Freshii  Vegetarian / Vegan Restaurant
# 3                                 Freshii  Vegetarian / Vegan Restaurant
# 4                            Milk N Honey  Vegetarian / Vegan Restaurant
# 5                                  nutbar  Vegetarian / Vegan Restaurant
# 6                                Cultures  Vegetarian / Vegan Restaurant
# 7               Afghan Village Restaurant      Middle Eastern Restaurant
# 0                             Zen Gardens  Vegetarian / Vegan Restaurant
# 1           Thrive Organic Kitchen & Café  Vegetarian / Vegan Restaurant
# 2                 Garam Masala Restaurant  Vegetarian / Vegan Restaurant
# 3                           Cold Pressery  Vegetarian / Vegan Restaurant
# 4                           Veggie Planet  Vegetarian / Vegan Restaurant
#
#           lat        lng                                         address  \
# 0   43.754221 -79.351665                              861 York Mills Rd.
# 1   43.769842 -79.281952                                 1975 Kennedy Rd
# 2   43.717216 -79.293808                                741 Pharmacy Ave
# 3   43.707324 -79.395649                         90 Eglinton Avenue East
# 4   43.819421 -79.294682                               3838 Midland Ave.
# 5   43.788118 -79.266678                   4466 Sheppard Ave. E Unit 101
# 6   43.679637 -79.341752                              1450 Danforth Ave.
# 7   43.672480 -79.321275                               1460 Gerrard St E
# 8   43.672114 -79.290331                             2188 Queen Street E
# 9   43.820629 -79.261592                    3300 McNicoll Ave (Unit 18A)
# 10  43.707127 -79.395801                         75 Eglinton Avenue East
# 11  43.828780 -79.306199                            8 - 7131 Kennedy Rd.
# 12  43.815757 -79.424567                                  7718 Yonge St.
# 13  43.670213 -79.389512                                 1221 Bay Street
# 14  43.667026 -79.345569                               797 Gerrard St E.
# 15  43.665890 -79.352650                                   385 Broadview
# 16  43.666755 -79.403491                                 326 Bloor St. W
# 17  43.677023 -79.396919                                   243 Avenue Rd
# 18  43.671104 -79.295107                             2116 Queen Street E
# 19  43.666588 -79.411777                             854 Bathurst Street
# 20  43.654972 -79.380856                                    220 Yonge St
# 21  43.675053 -79.406715                               264 Dupont Street
# 22  43.656016 -79.392758                                   17 Baldwin St
# 23  43.655454 -79.402439                                 238 Augusta Ave
# 24  43.657573 -79.402159                              310 College Street
# 25  43.674895 -79.406994                               270 Dupont Street
# 26  43.656193 -79.402673                                    64 Oxford St
# 27  43.648048 -79.396008                                147 Spadina Ave.
# 28  43.654270 -79.401897                                192 Augusta Ave.
# 29  43.655194 -79.418099                                 705 College St.
# 30  43.653699 -79.390743                                  109 McCaul St.
# 31  43.650252 -79.385156                               133 Richmond St W
# 32  43.657007 -79.405302                                  382 College St
# 33  43.654311 -79.399225                               6 Saint Andrew St
# 34  43.654010 -79.401805                              207 Augusta Avenue
# 35  43.647944 -79.396121                                 140 Spadina Ave
# 36  43.650319 -79.388998                                 255 Queen St. W
# 37  43.651904 -79.403312                               666 Dundas St. W.
# 38  43.648547 -79.381624                            100 King Street West
# 39  43.660524 -79.432525                                1056 Bloor St W.
# 40  43.655655 -79.402467                              242 Augusta Avenue
# 41  43.648014 -79.389694                        268 Adelaide Street West
# 42  43.672817 -79.414220                               1085 Bathurst St.
# 43  43.652034 -79.402382                                         Denison
# 44  43.806526 -79.288972                                3290 Midland Rd.
# 45  43.844056 -79.388412                           280 West Beaver Creek
# 46  43.649224 -79.422326                             1199 Dundas St West
# 47  43.641179 -79.378144                                88 Queens Quay W
# 48  43.649532 -79.427828                            1371 Dundas St. West
# 49  43.649259 -79.424022                                279 Roncesvalles
# 50  43.640044 -79.421433                               134 Atlantic Ave.
# 51  43.658455 -79.442291                             1277 Bloor St. West
# 52  43.643264 -79.423516                                 1122 Queen St W
# 53  43.644139 -79.402798                                  700 King St. W
# 54  43.650934 -79.379299                                 4 Temperance St
# 55  43.689047 -79.412819                                 446 Spadina Rd.
# 56  43.645488 -79.412575                           917 Queen Street West
# 57  43.678078 -79.349459                               489 Danforth Ave.
# 58  43.641690 -79.431195                              1346 Queen St West
# 59  43.671493 -79.325764                               1326 Gerrard St E
# 60  43.728425 -79.431733                                3457 Bathurst St
# 61  43.682811 -79.391945                                   1240 Yonge St
# 62  43.647717 -79.383916                                145 King St West
# 63  43.642848 -79.425369                                 1170 Queen St W
# 64  43.878170 -79.260913                                  116 Main St. N
# 65  43.713829 -79.334990                       747 Don Mills Rd., Unit 7
# 66  43.860039 -79.303280                                8362 Kennedy Rd.
# 67  43.646407 -79.379169                                  181 Bay Street
# 68  43.648773 -79.371614                                   92 Front St E
# 69  43.651102 -79.411654                                 885 Dundas West
# 70  43.847893 -79.357447                               8425 Woodbine Ave
# 71  43.725290 -79.451768                                 1 yorkdale road
# 72  43.641580 -79.431176                                1265 Queen St. W
# 73  43.661996 -79.394181            Lower Level, 9 King’s College Circle
# 74  43.664856 -79.387479                               56 Wellesley St W
# 75  43.650412 -79.478477                          2277 Bloor Street West
# 76  43.660804 -79.400365                              16 Bancroft Avenue
# 77  43.656287 -79.388830                              525 University Ave
# 78  43.659303 -79.382679                                382 Yonge Street
# 79  43.659806 -79.395084                            10 Kings College Rd.
# 80  43.665394 -79.409514                                        Bloor St
# 81  43.647888 -79.374586                               47 Front Street E
# 82  43.655044 -79.416344                                 661 College St.
# 83  43.648445 -79.382173                                   100 King St W
# 84  43.649804 -79.396820                                186 Spadina Ave.
# 85  43.648276 -79.385348                             154 University Ave.
# 86  43.645859 -79.392753                            367 King Street West
# 87  43.639879 -79.381234                               208 Queens Quay W
# 88  43.644085 -79.401444                            613 King Street West
# 89  43.849589 -79.459751                            9360 Bathurst Street
# 90  43.788524 -79.548479                                 7600 Weston Rd.
# 0   43.654972 -79.380856                                    220 Yonge St
# 1   43.665890 -79.352650                                   385 Broadview
# 2   43.648547 -79.381624                            100 King Street West
# 3   43.667026 -79.345569                               797 Gerrard St E.
# 4   43.650252 -79.385156                               133 Richmond St W
# 5   43.641179 -79.378144                                88 Queens Quay W
# 6   43.650319 -79.388998                                 255 Queen St. W
# 7   43.653699 -79.390743                                  109 McCaul St.
# 8   43.648014 -79.389694                        268 Adelaide Street West
# 9   43.650934 -79.379299                                 4 Temperance St
# 10  43.648773 -79.371614                                   92 Front St E
# 11  43.647717 -79.383916                                145 King St West
# 12  43.646407 -79.379169                                  181 Bay Street
# 13  43.647888 -79.374586                               47 Front Street E
# 14  43.648445 -79.382173                                   100 King St W
# 15  43.659303 -79.382679                                382 Yonge Street
# 16  43.656287 -79.388830                              525 University Ave
# 17  43.648276 -79.385348                             154 University Ave.
# 18  43.639879 -79.381234                               208 Queens Quay W
# 19  43.657746 -79.381628                                    351 Yonge St
# 20  43.664856 -79.387479                               56 Wellesley St W
# 0   43.656016 -79.392758                                   17 Baldwin St
# 1   43.670213 -79.389512                                 1221 Bay Street
# 2   43.654972 -79.380856                                    220 Yonge St
# 3   43.653699 -79.390743                                  109 McCaul St.
# 4   43.666755 -79.403491                                 326 Bloor St. W
# 5   43.657573 -79.402159                              310 College Street
# 6   43.655454 -79.402439                                 238 Augusta Ave
# 7   43.656193 -79.402673                                    64 Oxford St
# 8   43.654311 -79.399225                               6 Saint Andrew St
# 9   43.654270 -79.401897                                192 Augusta Ave.
# 10  43.654010 -79.401805                              207 Augusta Avenue
# 11  43.650319 -79.388998                                 255 Queen St. W
# 12  43.655655 -79.402467                              242 Augusta Avenue
# 13  43.650252 -79.385156                               133 Richmond St W
# 14  43.657007 -79.405302                                  382 College St
# 15  43.648048 -79.396008                                147 Spadina Ave.
# 16  43.651904 -79.403312                               666 Dundas St. W.
# 17  43.647944 -79.396121                                 140 Spadina Ave
# 18  43.652034 -79.402382                                         Denison
# 19  43.648014 -79.389694                        268 Adelaide Street West
# 20  43.677023 -79.396919                                   243 Avenue Rd
# 21  43.661996 -79.394181            Lower Level, 9 King’s College Circle
# 22  43.664856 -79.387479                               56 Wellesley St W
# 23  43.650934 -79.379299                                 4 Temperance St
# 24  43.659806 -79.395084                            10 Kings College Rd.
# 25  43.656287 -79.388830                              525 University Ave
# 26  43.659303 -79.382679                                382 Yonge Street
# 27  43.660804 -79.400365                              16 Bancroft Avenue
# 28  43.647717 -79.383916                                145 King St West
# 29  43.657746 -79.381628                                    351 Yonge St
# 30  43.670587 -79.385221                                  53 Bloor St. E
# 31  43.649804 -79.396820                                186 Spadina Ave.
# 32  43.648276 -79.385348                             154 University Ave.
# 33  43.645859 -79.392753                            367 King Street West
# 0   43.650412 -79.478477                          2277 Bloor Street West
# 1   43.660524 -79.432525                                1056 Bloor St W.
# 2   43.658455 -79.442291                             1277 Bloor St. West
# 3   43.649532 -79.427828                            1371 Dundas St. West
# 4   43.641690 -79.431195                              1346 Queen St West
# 5   43.595230 -79.530410                           3473 Lakeshore Blvd W
# 6   43.641580 -79.431176                                1265 Queen St. W
# 0   43.820629 -79.261592                    3300 McNicoll Ave (Unit 18A)
# 1   43.819421 -79.294682                               3838 Midland Ave.
# 2   43.788118 -79.266678                   4466 Sheppard Ave. E Unit 101
# 3   43.769842 -79.281952                                 1975 Kennedy Rd
# 4   43.828780 -79.306199                            8 - 7131 Kennedy Rd.
# 5   43.878170 -79.260913                                  116 Main St. N
# 6   43.860039 -79.303280                                8362 Kennedy Rd.
# 7   43.806526 -79.288972                                3290 Midland Rd.
# 0   43.672114 -79.290331                             2188 Queen Street E
# 1   43.717216 -79.293808                                741 Pharmacy Ave
# 2   43.672480 -79.321275                               1460 Gerrard St E
# 3   43.679637 -79.341752                              1450 Danforth Ave.
# 4   43.671104 -79.295107                             2116 Queen Street E
# 5   43.667026 -79.345569                               797 Gerrard St E.
# 6   43.665890 -79.352650                                   385 Broadview
# 7   43.707324 -79.395649                         90 Eglinton Avenue East
# 8   43.707127 -79.395801                         75 Eglinton Avenue East
# 9   43.671493 -79.325764                               1326 Gerrard St E
# 10  43.678078 -79.349459                               489 Danforth Ave.
# 11  43.713829 -79.334990                       747 Don Mills Rd., Unit 7
# 0   43.666588 -79.411777                             854 Bathurst Street
# 1   43.707324 -79.395649                         90 Eglinton Avenue East
# 2   43.666755 -79.403491                                 326 Bloor St. W
# 3   43.675053 -79.406715                               264 Dupont Street
# 4   43.660524 -79.432525                                1056 Bloor St W.
# 5   43.674895 -79.406994                               270 Dupont Street
# 6   43.677023 -79.396919                                   243 Avenue Rd
# 7   43.655194 -79.418099                                 705 College St.
# 8   43.670213 -79.389512                                 1221 Bay Street
# 9   43.672817 -79.414220                               1085 Bathurst St.
# 10  43.655454 -79.402439                                 238 Augusta Ave
# 11  43.657573 -79.402159                              310 College Street
# 12  43.658455 -79.442291                             1277 Bloor St. West
# 13  43.656193 -79.402673                                    64 Oxford St
# 14  43.656016 -79.392758                                   17 Baldwin St
# 15  43.657007 -79.405302                                  382 College St
# 16  43.654270 -79.401897                                192 Augusta Ave.
# 17  43.649224 -79.422326                             1199 Dundas St West
# 18  43.707127 -79.395801                         75 Eglinton Avenue East
# 19  43.654010 -79.401805                              207 Augusta Avenue
# 20  43.649532 -79.427828                            1371 Dundas St. West
# 21  43.651904 -79.403312                               666 Dundas St. W.
# 22  43.654311 -79.399225                               6 Saint Andrew St
# 23  43.655655 -79.402467                              242 Augusta Avenue
# 24  43.649259 -79.424022                                279 Roncesvalles
# 25  43.652034 -79.402382                                         Denison
# 26  43.689047 -79.412819                                 446 Spadina Rd.
# 27  43.645010 -79.415084                                 894 Queen St. W
# 28  43.645488 -79.412575                           917 Queen Street West
# 29  43.651102 -79.411654                                 885 Dundas West
# 30  43.682811 -79.391945                                   1240 Yonge St
# 31  43.665394 -79.409514                                        Bloor St
# 32  43.655044 -79.416344                                 661 College St.
# 33  43.728425 -79.431733                                3457 Bathurst St
# 34  43.660804 -79.400365                              16 Bancroft Avenue
# 35  43.725290 -79.451768                                 1 yorkdale road
# 36  43.661996 -79.394181            Lower Level, 9 King’s College Circle
# 37  43.664856 -79.387479                               56 Wellesley St W
# 38  43.659806 -79.395084                            10 Kings College Rd.
# 39  43.670587 -79.385221                                  53 Bloor St. E
# 40  43.659303 -79.382679                                382 Yonge Street
# 0   43.672114 -79.290331                             2188 Queen Street E
# 1   43.671104 -79.295107                             2116 Queen Street E
# 2   43.672480 -79.321275                               1460 Gerrard St E
# 3   43.679637 -79.341752                              1450 Danforth Ave.
# 4   43.667026 -79.345569                               797 Gerrard St E.
# 5   43.665890 -79.352650                                   385 Broadview
# 6   43.717216 -79.293808                                741 Pharmacy Ave
# 7   43.641179 -79.378144                                88 Queens Quay W
# 8   43.671493 -79.325764                               1326 Gerrard St E
# 9   43.650934 -79.379299                                 4 Temperance St
# 10  43.678078 -79.349459                               489 Danforth Ave.
# 11  43.646407 -79.379169                                  181 Bay Street
# 12  43.648773 -79.371614                                   92 Front St E
# 13  43.647888 -79.374586                               47 Front Street E
# 14  43.713829 -79.334990                       747 Don Mills Rd., Unit 7
# 0   43.660524 -79.432525                                1056 Bloor St W.
# 1   43.658455 -79.442291                             1277 Bloor St. West
# 2   43.655194 -79.418099                                 705 College St.
# 3   43.666588 -79.411777                             854 Bathurst Street
# 4   43.649532 -79.427828                            1371 Dundas St. West
# 5   43.649224 -79.422326                             1199 Dundas St West
# 6   43.666755 -79.403491                                 326 Bloor St. W
# 7   43.649259 -79.424022                                279 Roncesvalles
# 8   43.675053 -79.406715                               264 Dupont Street
# 9   43.672817 -79.414220                               1085 Bathurst St.
# 10  43.657573 -79.402159                              310 College Street
# 11  43.657007 -79.405302                                  382 College St
# 12  43.641690 -79.431195                              1346 Queen St West
# 13  43.656193 -79.402673                                    64 Oxford St
# 14  43.640044 -79.421433                               134 Atlantic Ave.
# 15  43.645010 -79.415084                                 894 Queen St. W
# 16  43.643264 -79.423516                                 1122 Queen St W
# 17  43.674895 -79.406994                               270 Dupont Street
# 18  43.651904 -79.403312                               666 Dundas St. W.
# 19  43.642848 -79.425369                                 1170 Queen St W
# 20  43.677023 -79.396919                                   243 Avenue Rd
# 21  43.645488 -79.412575                           917 Queen Street West
# 22  43.650412 -79.478477                          2277 Bloor Street West
# 23  43.641580 -79.431176                                1265 Queen St. W
# 24  43.651102 -79.411654                                 885 Dundas West
# 25  43.655044 -79.416344                                 661 College St.
# 26  43.689047 -79.412819                                 446 Spadina Rd.
# 27  43.665394 -79.409514                                        Bloor St
# 28  43.660804 -79.400365                              16 Bancroft Avenue
# 29  43.661996 -79.394181            Lower Level, 9 King’s College Circle
# 0   43.707324 -79.395649                         90 Eglinton Avenue East
# 1   43.707127 -79.395801                         75 Eglinton Avenue East
# 2   43.754221 -79.351665                              861 York Mills Rd.
# 3   43.689047 -79.412819                                 446 Spadina Rd.
# 4   43.728425 -79.431733                                3457 Bathurst St
# 5   43.682811 -79.391945                                   1240 Yonge St
# 6   43.725290 -79.451768                                 1 yorkdale road
# 7   43.713829 -79.334990                       747 Don Mills Rd., Unit 7
# 0   43.643170 -79.708610                          6980 Maritz Dr, Unit 6
# 1   43.595230 -79.530410                           3473 Lakeshore Blvd W
# 2   43.614082 -79.661988                             40 Bristol Street E
# 3   43.599358 -79.641222             4310 Sherwoodtowne Blvd. (Suite #5)
# 4   43.673110 -79.675766  6985 Davand Dr Unit #1, Mississauga, ON L5T1Y7
#
#              Borough
# 0         North York
# 1         North York
# 2         North York
# 3         North York
# 4         North York
# 5         North York
# 6         North York
# 7         North York
# 8         North York
# 9         North York
# 10        North York
# 11        North York
# 12        North York
# 13        North York
# 14        North York
# 15        North York
# 16        North York
# 17        North York
# 18        North York
# 19        North York
# 20        North York
# 21        North York
# 22        North York
# 23        North York
# 24        North York
# 25        North York
# 26        North York
# 27        North York
# 28        North York
# 29        North York
# 30        North York
# 31        North York
# 32        North York
# 33        North York
# 34        North York
# 35        North York
# 36        North York
# 37        North York
# 38        North York
# 39        North York
# 40        North York
# 41        North York
# 42        North York
# 43        North York
# 44        North York
# 45        North York
# 46        North York
# 47        North York
# 48        North York
# 49        North York
# 50        North York
# 51        North York
# 52        North York
# 53        North York
# 54        North York
# 55        North York
# 56        North York
# 57        North York
# 58        North York
# 59        North York
# 60        North York
# 61        North York
# 62        North York
# 63        North York
# 64        North York
# 65        North York
# 66        North York
# 67        North York
# 68        North York
# 69        North York
# 70        North York
# 71        North York
# 72        North York
# 73        North York
# 74        North York
# 75        North York
# 76        North York
# 77        North York
# 78        North York
# 79        North York
# 80        North York
# 81        North York
# 82        North York
# 83        North York
# 84        North York
# 85        North York
# 86        North York
# 87        North York
# 88        North York
# 89        North York
# 90        North York
# 0   Downtown Toronto
# 1   Downtown Toronto
# 2   Downtown Toronto
# 3   Downtown Toronto
# 4   Downtown Toronto
# 5   Downtown Toronto
# 6   Downtown Toronto
# 7   Downtown Toronto
# 8   Downtown Toronto
# 9   Downtown Toronto
# 10  Downtown Toronto
# 11  Downtown Toronto
# 12  Downtown Toronto
# 13  Downtown Toronto
# 14  Downtown Toronto
# 15  Downtown Toronto
# 16  Downtown Toronto
# 17  Downtown Toronto
# 18  Downtown Toronto
# 19  Downtown Toronto
# 20  Downtown Toronto
# 0       Queen's Park
# 1       Queen's Park
# 2       Queen's Park
# 3       Queen's Park
# 4       Queen's Park
# 5       Queen's Park
# 6       Queen's Park
# 7       Queen's Park
# 8       Queen's Park
# 9       Queen's Park
# 10      Queen's Park
# 11      Queen's Park
# 12      Queen's Park
# 13      Queen's Park
# 14      Queen's Park
# 15      Queen's Park
# 16      Queen's Park
# 17      Queen's Park
# 18      Queen's Park
# 19      Queen's Park
# 20      Queen's Park
# 21      Queen's Park
# 22      Queen's Park
# 23      Queen's Park
# 24      Queen's Park
# 25      Queen's Park
# 26      Queen's Park
# 27      Queen's Park
# 28      Queen's Park
# 29      Queen's Park
# 30      Queen's Park
# 31      Queen's Park
# 32      Queen's Park
# 33      Queen's Park
# 0          Etobicoke
# 1          Etobicoke
# 2          Etobicoke
# 3          Etobicoke
# 4          Etobicoke
# 5          Etobicoke
# 6          Etobicoke
# 0        Scarborough
# 1        Scarborough
# 2        Scarborough
# 3        Scarborough
# 4        Scarborough
# 5        Scarborough
# 6        Scarborough
# 7        Scarborough
# 0          East York
# 1          East York
# 2          East York
# 3          East York
# 4          East York
# 5          East York
# 6          East York
# 7          East York
# 8          East York
# 9          East York
# 10         East York
# 11         East York
# 0               York
# 1               York
# 2               York
# 3               York
# 4               York
# 5               York
# 6               York
# 7               York
# 8               York
# 9               York
# 10              York
# 11              York
# 12              York
# 13              York
# 14              York
# 15              York
# 16              York
# 17              York
# 18              York
# 19              York
# 20              York
# 21              York
# 22              York
# 23              York
# 24              York
# 25              York
# 26              York
# 27              York
# 28              York
# 29              York
# 30              York
# 31              York
# 32              York
# 33              York
# 34              York
# 35              York
# 36              York
# 37              York
# 38              York
# 39              York
# 40              York
# 0       East Toronto
# 1       East Toronto
# 2       East Toronto
# 3       East Toronto
# 4       East Toronto
# 5       East Toronto
# 6       East Toronto
# 7       East Toronto
# 8       East Toronto
# 9       East Toronto
# 10      East Toronto
# 11      East Toronto
# 12      East Toronto
# 13      East Toronto
# 14      East Toronto
# 0       West Toronto
# 1       West Toronto
# 2       West Toronto
# 3       West Toronto
# 4       West Toronto
# 5       West Toronto
# 6       West Toronto
# 7       West Toronto
# 8       West Toronto
# 9       West Toronto
# 10      West Toronto
# 11      West Toronto
# 12      West Toronto
# 13      West Toronto
# 14      West Toronto
# 15      West Toronto
# 16      West Toronto
# 17      West Toronto
# 18      West Toronto
# 19      West Toronto
# 20      West Toronto
# 21      West Toronto
# 22      West Toronto
# 23      West Toronto
# 24      West Toronto
# 25      West Toronto
# 26      West Toronto
# 27      West Toronto
# 28      West Toronto
# 29      West Toronto
# 0    Central Toronto
# 1    Central Toronto
# 2    Central Toronto
# 3    Central Toronto
# 4    Central Toronto
# 5    Central Toronto
# 6    Central Toronto
# 7    Central Toronto
# 0        Mississauga
# 1        Mississauga
# 2        Mississauga
# 3        Mississauga
# 4        Mississauga

# %% [markdown]
# ## Discussion Section

# %% [markdown]
# Since there are many restaurants present per borough we group the restaurants in a borough. We calculate the number of restaurants in every borough.

# %%
veggroup= veg_df["Borough"].groupby(veg_df["Borough"])
veggroup= veggroup.count()
veggroup
# Out:
# Borough
# Central Toronto      8
# Downtown Toronto    21
# East Toronto        15
# East York           12
# Etobicoke            7
# Mississauga          5
# North York          91
# Queen's Park        34
# Scarborough          8
# West Toronto        30
# York                41
# Name: Borough, dtype: int64

# %% [markdown]
# Based on the number of restaurants present in different boroughs, Mississauga should be the first choice to open a vegan or vegetarian restaurant.

# %% [markdown]
# ## Conclusion section

# %%
venues_map = folium.Map(location=[43.653963, -79.387207], zoom_start=12) # generate map centred around E
for lat, lng, label in zip(veg_df['lat'], veg_df['lng'], veg_df['name']):
        
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6,
            parse_html=False
        ).add_to(venues_map)

# %%
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Thus, we see that some boroughs have a few number of vegan or vegetarian restaurants whereas others have a large number of vegan or vegetarian restaurants. Based on the number of restaurants present in different boroughs, Mississauga should be the first choice to open a vegan or vegetarian restaurant. Followed by Etobicoke, Central Toronto, Scarborough, East York, East Toronto, Downtown Toronto, West Toronto, Queen's Park, York, North York.
